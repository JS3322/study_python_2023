# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import PCA
import numpy as np

# %matplotlib inline

# load Iris datasets 
iris = datasets.load_iris()

# here we only select sepal length and width (select first 2 columns)
X = iris.data[:, :2]  
y = iris.target

# visualization을 위하여 lim 설정
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5

plt.figure(figsize=(8, 6))

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1, edgecolor='k')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.show()

# %%
# PCA : 주성분 분석 (principal component analysis) : 고차원의 데이터를 저차원 데이터로 환원시키는 기법
fig = plt.figure(figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
ax.plot(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], marker='o', s=15, cmap='Greens')

# %%
X_reduced[:, 2]
# Out:
# array([-0.02791483, -0.21046427,  0.01790026,  0.03155937,  0.09007924,
#         0.16867766,  0.25789216, -0.02187932,  0.02075957, -0.19763272,
#        -0.07531801,  0.10215026, -0.20684443,  0.06129967, -0.15162752,
#         0.2777769 ,  0.13818323,  0.02666832, -0.12030552,  0.21366517,
#        -0.23944404,  0.20845723,  0.29239675,  0.03912326,  0.12502108,
#        -0.25342004,  0.09491058, -0.07849421, -0.1459089 ,  0.04077108,
#        -0.07722299, -0.14552497,  0.22566915,  0.15781081, -0.14304958,
#        -0.16433231, -0.26835038,  0.09369908,  0.07292705, -0.0800823 ,
#         0.07724769, -0.34923038,  0.19250921,  0.26386795,  0.29874275,
#        -0.09767814,  0.16670564,  0.08372685, -0.01711502, -0.08929401,
#        -0.40656803, -0.01801419, -0.33832576, -0.17959139, -0.3077579 ,
#         0.04107609,  0.16981024,  0.01230292, -0.41533608,  0.28114143,
#        -0.26981718,  0.13054775, -0.69414683, -0.06211441,  0.09045769,
# ...

# %%
cmin, cmax = 0, 2
color = np.array([(cmax - cmin) * np.random.random_sample() + cmin for i in range(n)])

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

ax.plot(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2],  marker='o')

plt.show()
