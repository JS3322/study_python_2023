# %%
# use polars : pip3 install polars
import polars as pl
from sklearn import datasets

import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/jmnote/zdata/master/R/iris.csv")
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data = pl.read_csv("https://raw.githubusercontent.com/jmnote/zdata/master/R/iris.csv")
data
# Out:
# shape: (150, 5)
# ┌──────────────┬─────────────┬──────────────┬─────────────┬───────────┐
# │ Sepal.Length ┆ Sepal.Width ┆ Petal.Length ┆ Petal.Width ┆ Species   │
# │ ---          ┆ ---         ┆ ---          ┆ ---         ┆ ---       │
# │ f64          ┆ f64         ┆ f64          ┆ f64         ┆ str       │
# ╞══════════════╪═════════════╪══════════════╪═════════════╪═══════════╡
# │ 5.1          ┆ 3.5         ┆ 1.4          ┆ 0.2         ┆ setosa    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 4.9          ┆ 3.0         ┆ 1.4          ┆ 0.2         ┆ setosa    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 4.7          ┆ 3.2         ┆ 1.3          ┆ 0.2         ┆ setosa    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 4.6          ┆ 3.1         ┆ 1.5          ┆ 0.2         ┆ setosa    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# ...

# %%
t = data.filter(pl.col("Sepal.Length"))
# Out:
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 t = data.filter(pl.col("Sepal.Length"))
#
# File /opt/conda/lib/python3.10/site-packages/polars/internals/dataframe/frame.py:2590, in DataFrame.filter(self, predicate)
#    2586 if _NUMPY_TYPE(predicate) and isinstance(predicate, np.ndarray):
#    2587     predicate = pli.Series(predicate)
#    2589 return (
# -> 2590     self.lazy()
#    2591     .filter(predicate)  # type: ignore[arg-type]
#    2592     .collect(no_optimization=True)
#    2593 )
#
# File /opt/conda/lib/python3.10/site-packages/polars/utils.py:337, in deprecated_alias.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     334 @functools.wraps(fn)
#     335 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     336     _rename_kwargs(fn.__name__, kwargs, aliases)
# --> 337     return fn(*args, **kwargs)
#
# ...

# %%
q = (
    pl.read_csv("https://raw.githubusercontent.com/jmnote/zdata/master/R/iris.csv")
    .filter(pl.col("sepal_length") > 5)
    .groupby("species")
    .agg(pl.all().sum())
)

df = q.collect()
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[16], line 3
#       1 q = (
#       2     pl.read_csv("https://raw.githubusercontent.com/jmnote/zdata/master/R/iris.csv")
# ----> 3     .filter(pl.col("sepal_length") > 5)
#       4     .groupby("species")
#       5     .agg(pl.all().sum())
#       6 )
#       8 df = q.collect()
#
# File /opt/conda/lib/python3.10/site-packages/polars/internals/dataframe/frame.py:2590, in DataFrame.filter(self, predicate)
#    2586 if _NUMPY_TYPE(predicate) and isinstance(predicate, np.ndarray):
#    2587     predicate = pli.Series(predicate)
#    2589 return (
# -> 2590     self.lazy()
#    2591     .filter(predicate)  # type: ignore[arg-type]
#    2592     .collect(no_optimization=True)
#    2593 )
#
# File /opt/conda/lib/python3.10/site-packages/polars/utils.py:337, in deprecated_alias.<locals>.deco.<locals>.wrapper(*args, **kwargs)
# ...
