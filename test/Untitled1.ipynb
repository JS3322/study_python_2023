# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('health.csv')

# %%
data.plot(x='ym', y='price')
plt.xlabel('ym')
plt.ylabel('price')
# plt.xticks(range(data['ym'][0], data['ym'][100]), range(data['ym'][0], data['ym'][100]))
data['ym'][last]
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 5
#       3 plt.ylabel('price')
#       4 # plt.xticks(range(data['ym'][0], data['ym'][100]), range(data['ym'][0], data['ym'][100]))
# ----> 5 data['ym'][last]
#       6 # plt.show()
#
# NameError: name 'last' is not defined

# %%
data
# Out:
#     Unnamed: 0      연월        이용금액
# 0            0  201801   328273485
# 1            1  201802   570907937
# 2            2  201803   478457437
# 3            3  201804   719701442
# 4            4  201805   608697453
# 5            5  201806   613084464
# 6            6  201807   497119351
# 7            7  201808   477369424
# 8            8  201809   737866289
# 9            9  201810   774794209
# 10          10  201811   969895231
# 11          11  201812   848872458
# 12          12  201901   820125140
# 13          13  201902   706146940
# 14          14  201903  1109888456
# 15          15  201904  1045109330
# 16          16  201905  1207967163
# 17          17  201906  1118683103
# 18          18  201907  1191892824
# 19          19  201908  1044014273
# 20          20  201909  1187206567
# 21          21  201910  1287465659
# 22          22  201911   964633208
# 23          23  201912  1522077229
# 24          24  202001  3436009340
# 25          25  202002  1156258241
# ...
